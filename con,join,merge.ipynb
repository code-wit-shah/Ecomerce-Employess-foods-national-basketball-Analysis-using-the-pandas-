# %%
import pandas as pd

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
pd.concat(objs=[week1,week2],ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
sales=pd.concat(objs=[week1,week2],keys=["week1","week2"])

# %%
sales
# Out:
#            Customer ID  Food ID
# week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
# ...                ...      ...
# week2 245          783       10
#       246          556       10
#       247          547        9
#       248          252        9
#       249          249        6
#
# [500 rows x 2 columns]

# %%
sales.loc[("week1",)]
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
sales.loc[("week2")]
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
sales.loc[("week2",240)]
# Out:
# Customer ID    734
# Food ID          1
# Name: (week2, 240), dtype: int64

# %%
sales.loc[("week1",240)]
# Out:
# Customer ID    945
# Food ID          5
# Name: (week1, 240), dtype: int64

# %%
sales.loc[("week1",240),"Customer ID"]
# Out:
# 945

# %%
sales.loc[("week1",240),["Customer ID","Food ID"]]
# Out:
# Customer ID    945
# Food ID          5
# Name: (week1, 240), dtype: int64

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2,how="inner",on="Customer ID",suffixes=["-A","-B"])
# Out:
#     Customer ID  Food ID-A  Food ID-B
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# ..          ...        ...        ...
# 57          945          5          4
# 58          343          3          5
# 59          343          3          2
# 60          343          3          7
# 61          621          9          6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"]==155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"]==155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.merge(week2,how="inner",on=["Customer ID","Food ID"],suffixes=["-A","-B"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"]==922]
# Out:
#      Customer ID  Food ID
# 121          922        1

# %%
week2[week2["Customer ID"]==922]
# Out:
#      Customer ID  Food ID
# 45           922        1
# 170          922        2

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
merge=week1.merge(week2,how="outer",on="Customer ID",suffixes=["-week1","-week2"],indicator=True)

# %%
merge["_merge"].value_counts()
# Out:
# _merge
# right_only    197
# left_only     195
# both           62
# Name: count, dtype: int64

# %%
mask=merge["_merge"].isin(["left_only","right_only"])
merge[mask]
# Out:
#      Customer ID  Food ID-week1  Food ID-week2      _merge
# 1             97            4.0            NaN   left_only
# 2            658            1.0            NaN   left_only
# 3            202            2.0            NaN   left_only
# 6            213            8.0            NaN   left_only
# 7            600            1.0            NaN   left_only
# ..           ...            ...            ...         ...
# 449          855            NaN            4.0  right_only
# 450          559            NaN           10.0  right_only
# 451          276            NaN            4.0  right_only
# 452          556            NaN           10.0  right_only
# 453          252            NaN            9.0  right_only
#
# [392 rows x 4 columns]

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1=week1.merge(foods,how="left",on="Food ID",sort=True)
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2=week2.merge(customers,how="left",left_on="Customer ID",right_on="ID").drop("ID",axis=1)

# %%
week2.head()
# Out:
#    Customer ID  Food ID First Name   Last Name  Gender     Company  \
# 0          688       10       Carl  Williamson    Male  Thoughtmix
# 1          813        7     Johnny      Walker    Male      Kayveo
# 2          495       10    Deborah      Little  Female  Babbleblab
# 3          189        5      Roger      Gordon    Male     Skilith
# 4          267        3    Matthew        Wood    Male      Agimba
#
#          Occupation
# 0  Graphic Designer
# 1      Developer II
# 2     VP Accounting
# 3          Operator
# 4  Product Engineer

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv",index_col="ID")
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head()
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive
# 4      Steven     Evans    Male     Fatz               Registered Nurse
# 5        Judy  Morrison  Female  Demivee                Legal Assistant

# %%
sales=week1.merge(customers, how="left", left_on="Customer ID", right_index=True)

# %%
sales.merge(foods,how="left",left_on="Food ID",right_index=True).tail(45)
# Out:
#      Customer ID  Food ID_x First Name Last Name  Gender       Company  \
# 205          798          1      Kelly    Taylor  Female         Meejo
# 206          606          7  Christina    Morgan  Female         Yodoo
# 207          100          4       Lois    Howard  Female         Voomm
# 208          783          6    Phyllis     Meyer  Female        Voolia
# 209          985          5      Julia     Ortiz  Female        Kwideo
# 210          123          6      Craig      Cruz    Male          Latz
# 211          809         10       Lisa     Ellis  Female  Twitterworks
# 212           21          4     Albert     Burns    Male     Rhynoodle
# 213          764          9    Rebecca    Hanson  Female     Topicware
# 214           92          1     Justin   Roberts    Male   Twitterlist
# 215          386          6      Kevin   Vasquez    Male       Gigabox
# 216          331          3       Eric   Elliott    Male       Skilith
# 217           62          5     Andrew    Tucker    Male        Leenti
# 218           91          8    Theresa     Adams  Female    Brainverse
# 219          368          6      Jason    Barnes    Male      Skipfire
# 220          147          8    Theresa   Morales  Female         Abata
# 221          745          4     Nicole     Garza  Female     Topiczoom
# 222          184          3      Jesse   Edwards    Male      Zoombeat
# 223          828          8       Mary     Payne  Female       Oyonder
# 224          578          5     Donald  Matthews    Male      Fiveclub
# 225          491          4       Anna   Perkins  Female         Zazio
# 226           62          4     Andrew    Tucker    Male        Leenti
# 227           77          9       Lori   Edwards  Female       Dabvine
# 228          506          9    Mildred   Mendoza  Female          Vitz
# 229          271          9    Beverly      Ward  Female      Brainbox
# 230          584         10    Jeffrey   Simmons    Male     Flipstorm
# 231          148          5   Patricia      Reid  Female  Shuffledrive
# 232          595          3      Bruce   Kennedy    Male          Mydo
# 233          274         10       Gary      Reid    Male      Fivespan
# 234          646          1      Wanda      Lane  Female         Twiyo
# 235          520          8    Melissa   Wallace  Female         Skyvu
# 236          644          8      Louis    Brooks    Male       Nlounge
# 237          725          8      Carol   Russell  Female        BlogXS
# 238          934          4     Joseph    Burton    Male         Leexo
# 239          151         10    Brandon    Oliver    Male         Voomm
# 240          945          5       Anne      Reed  Female  Twitterworks
# 241          343          3        Joe     Price    Male      Fanoodle
# 242          380          9     Martha     Payne  Female         Quinu
# 243          911          4    Patrick      Reed    Male   Jabberstorm
# 244          621          9        Amy      Long  Female        Skidoo
# 245          413          9      Diane    Bailey  Female       Wikibox
# 246          926          6       Anne    Wagner  Female         Skyba
# 247          134          3      Diana      Hall  Female         Quinu
# 248          396          6       Juan    Romero    Male       Zoonder
# 249          535         10      Nancy       Cox  Female        Trudeo
#
#                         Occupation  Food ID_y   Food Item  Price
# 205                Design Engineer        2.0     Burrito   9.99
# 206               Dental Hygienist        8.0       Salad  11.25
# 207       Systems Administrator IV        5.0       Pizza   2.49
# 208    Information Systems Manager        7.0       Steak  24.99
# 209   Structural Analysis Engineer        6.0       Pasta  13.99
# 210                         Editor        7.0       Steak  24.99
# 211     Quality Control Specialist        NaN         NaN    NaN
# 212               Junior Executive        5.0       Pizza   2.49
# 213               Junior Executive       10.0       Drink   1.75
# 214              Assistant Manager        2.0     Burrito   9.99
# 215                   Geologist II        7.0       Steak  24.99
# 216       Senior Financial Analyst        4.0  Quesadilla   4.25
# 217   Structural Analysis Engineer        6.0       Pasta  13.99
# 218               Junior Executive        9.0       Donut   0.99
# 219             Staff Accountant I        7.0       Steak  24.99
# 220         Occupational Therapist        9.0       Donut   0.99
# 221                General Manager        5.0       Pizza   2.49
# 222         Administrative Officer        4.0  Quesadilla   4.25
# 223        Assistant Media Planner        9.0       Donut   0.99
# 224     Physical Therapy Assistant        6.0       Pasta  13.99
# 225               Quality Engineer        5.0       Pizza   2.49
# 226   Structural Analysis Engineer        5.0       Pizza   2.49
# 227           Sales Representative       10.0       Drink   1.75
# 228             Environmental Tech       10.0       Drink   1.75
# 229       Automation Specialist II       10.0       Drink   1.75
# 230              Chemical Engineer        NaN         NaN    NaN
# 231  Analog Circuit Design manager        6.0       Pasta  13.99
# 232                      Recruiter        4.0  Quesadilla   4.25
# 233            Executive Secretary        NaN         NaN    NaN
# 234           Help Desk Technician        2.0     Burrito   9.99
# 235         Administrative Officer        9.0       Donut   0.99
# 236             VP Quality Control        9.0       Donut   0.99
# 237                     Pharmacist        9.0       Donut   0.99
# 238           Compensation Analyst        5.0       Pizza   2.49
# 239               Internal Auditor        NaN         NaN    NaN
# 240              Director of Sales        6.0       Pasta  13.99
# 241              Marketing Manager        4.0  Quesadilla   4.25
# 242        Assistant Media Planner       10.0       Drink   1.75
# 243        Senior Quality Engineer        5.0       Pizza   2.49
# 244             Research Associate       10.0       Drink   1.75
# 245               Technical Writer       10.0       Drink   1.75
# 246                Legal Assistant        7.0       Steak  24.99
# 247              Financial Advisor        4.0  Quesadilla   4.25
# 248             Analyst Programmer        7.0       Steak  24.99
# 249             Research Associate        NaN         NaN    NaN

# %%
week1.merge(week2,how="left",left_index=True,right_index=True)
# Out:
#      Customer ID_x  Food ID_x  Customer ID_y  Food ID_y
# 0              537          9            688         10
# 1               97          4            813          7
# 2              658          1            495         10
# 3              202          2            189          5
# 4              155          9            267          3
# ..             ...        ...            ...        ...
# 245            413          9            783         10
# 246            926          6            556         10
# 247            134          3            547          9
# 248            396          6            252          9
# 249            535         10            249          6
#
# [250 rows x 4 columns]

# %%
week1.merge(customers, how="left", left_on="Customer ID", right_index=True)
# Out:
#      Customer ID  Food ID     ID First Name   Last Name  Gender       Company  \
# 0            537        9  538.0       Sara  Washington  Female        Skimia
# 1             97        4   98.0       Jean       Mills  Female    Fivebridge
# 2            658        1  659.0     Howard      Hudson    Male    Topicshots
# 3            202        2  203.0      Annie        Lane  Female        Skyble
# 4            155        9  156.0  Stephanie       Kelly  Female       Youopia
# ..           ...      ...    ...        ...         ...     ...           ...
# 245          413        9  414.0     Harold       Adams    Male  Dazzlesphere
# 246          926        6  927.0   Nicholas      Morris    Male    Linkbridge
# 247          134        3  135.0    Richard      Murphy    Male       Cogidoo
# 248          396        6  397.0     Brenda        Ryan  Female          Oozz
# 249          535       10  536.0       Sara        Dean  Female        Skidoo
#
#                      Occupation
# 0    Database Administrator III
# 1              Product Engineer
# 2                     Professor
# 3             Marketing Manager
# 4     Automation Specialist III
# ..                          ...
# 245         Account Coordinator
# 246         Assistant Professor
# 247         Software Consultant
# 248          Nurse Practicioner
# 249                   Recruiter
#
# [250 rows x 8 columns]

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv") 
satisfaction=pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.merge(satisfaction,how="left",left_index=True,right_index=True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
customers.head(2)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
pd.merge(week1,customers,how="left",left_on="Customer ID",right_on="ID")
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0            537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1             97        4   97     Amanda   Watkins  Female        Ozu
# 2            658        1  658    Patrick      Webb    Male  Browsebug
# 3            202        2  202      Louis  Campbell    Male  Rhynoodle
# 4            155        9  155    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...  ...        ...       ...     ...        ...
# 245          413        9  413      Diane    Bailey  Female    Wikibox
# 246          926        6  926       Anne    Wagner  Female      Skyba
# 247          134        3  134      Diana      Hall  Female      Quinu
# 248          396        6  396       Juan    Romero    Male    Zoonder
# 249          535       10  535      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# 3       Account Representative III
# 4       Database Administrator III
# ..                             ...
# 245               Technical Writer
# 246                Legal Assistant
# 247              Financial Advisor
# 248             Analyst Programmer
# 249             Research Associate
#
# [250 rows x 8 columns]
