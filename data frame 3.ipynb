# %%
import pandas as pd

# %%
bond=pd.read_csv("jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index(keys="Film",inplace =True)

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.set_index("Year")
# Out:
#                Actor            Director  Box Office  Budget  \
# Year
# 1962    Sean Connery       Terence Young       448.8     7.0
# 1963    Sean Connery       Terence Young       543.8    12.6
# 1964    Sean Connery        Guy Hamilton       820.4    18.6
# 1965    Sean Connery       Terence Young       848.1    41.9
# 1967     David Niven          Ken Hughes       315.0    85.0
# 1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 1971    Sean Connery        Guy Hamilton       442.5    34.7
# 1973     Roger Moore        Guy Hamilton       460.3    30.8
# 1974     Roger Moore        Guy Hamilton       334.0    27.7
# 1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 1981     Roger Moore           John Glen       449.4    60.2
# 1983    Sean Connery      Irvin Kershner       380.0    86.0
# ...

# %%
bond.set_index("Actor")
# Out:
#                 Year            Director  Box Office  Budget  \
# Actor
# Sean Connery    1962       Terence Young       448.8     7.0
# Sean Connery    1963       Terence Young       543.8    12.6
# Sean Connery    1964        Guy Hamilton       820.4    18.6
# Sean Connery    1965       Terence Young       848.1    41.9
# David Niven     1967          Ken Hughes       315.0    85.0
# Sean Connery    1967       Lewis Gilbert       514.2    59.9
# George Lazenby  1969       Peter R. Hunt       291.5    37.3
# Sean Connery    1971        Guy Hamilton       442.5    34.7
# Roger Moore     1973        Guy Hamilton       460.3    30.8
# Roger Moore     1974        Guy Hamilton       334.0    27.7
# Roger Moore     1977       Lewis Gilbert       533.0    45.1
# Roger Moore     1979       Lewis Gilbert       535.0    91.5
# Roger Moore     1981           John Glen       449.4    60.2
# Sean Connery    1983      Irvin Kershner       380.0    86.0
# ...

# %%
bond.reset_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(drop=False)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(drop=True)
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
bond.set_index("Year")
# Out:
#                Actor            Director  Box Office  Budget  \
# Year
# 1962    Sean Connery       Terence Young       448.8     7.0
# 1963    Sean Connery       Terence Young       543.8    12.6
# 1964    Sean Connery        Guy Hamilton       820.4    18.6
# 1965    Sean Connery       Terence Young       848.1    41.9
# 1967     David Niven          Ken Hughes       315.0    85.0
# 1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 1971    Sean Connery        Guy Hamilton       442.5    34.7
# 1973     Roger Moore        Guy Hamilton       460.3    30.8
# 1974     Roger Moore        Guy Hamilton       334.0    27.7
# 1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 1981     Roger Moore           John Glen       449.4    60.2
# 1983    Sean Connery      Irvin Kershner       380.0    86.0
# ...

# %%
bond.set_index("Actor")
# Out:
#                 Year            Director  Box Office  Budget  \
# Actor
# Sean Connery    1962       Terence Young       448.8     7.0
# Sean Connery    1963       Terence Young       543.8    12.6
# Sean Connery    1964        Guy Hamilton       820.4    18.6
# Sean Connery    1965       Terence Young       848.1    41.9
# David Niven     1967          Ken Hughes       315.0    85.0
# Sean Connery    1967       Lewis Gilbert       514.2    59.9
# George Lazenby  1969       Peter R. Hunt       291.5    37.3
# Sean Connery    1971        Guy Hamilton       442.5    34.7
# Roger Moore     1973        Guy Hamilton       460.3    30.8
# Roger Moore     1974        Guy Hamilton       334.0    27.7
# Roger Moore     1977       Lewis Gilbert       533.0    45.1
# Roger Moore     1979       Lewis Gilbert       535.0    91.5
# Roger Moore     1981           John Glen       449.4    60.2
# Sean Connery    1983      Irvin Kershner       380.0    86.0
# ...

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc["GoldenEye"]
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.loc["From Russia with Love":"You Only Live Twice"]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
# You Only Live Twice    1967  Sean Connery  Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN
# You Only Live Twice                  4.4

# %%
bond.loc[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Thunderball                           848.1    41.9                4.7
# ...

# %%
bond.loc[["Die Another Day","Octopussy"]]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8

# %%
"Gold Bond" in bond.index
# Out:
# False

# %%
bond.iloc[15]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[[10,20]]
# Out:
#                          Year           Actor       Director  Box Office  \
# Film
# The Spy Who Loved Me     1977     Roger Moore  Lewis Gilbert       533.0
# The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#                          Budget  Bond Actor Salary
# Film
# The Spy Who Loved Me       45.1                NaN
# The World Is Not Enough   158.3               13.5

# %%
bond.iloc[4:8]
# Out:
#                                  Year           Actor       Director  \
# Film
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale                         315.0    85.0                NaN
# You Only Live Twice                   514.2    59.9                4.4
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8

# %%
bond.iloc[20:]
# Out:
#                          Year           Actor         Director  Box Office  \
# Film
# The World Is Not Enough  1999  Pierce Brosnan    Michael Apted       439.5
# Die Another Day          2002  Pierce Brosnan     Lee Tamahori       465.4
# Casino Royale            2006    Daniel Craig  Martin Campbell       581.5
# Quantum of Solace        2008    Daniel Craig     Marc Forster       514.2
# Skyfall                  2012    Daniel Craig       Sam Mendes       943.5
# Spectre                  2015    Daniel Craig       Sam Mendes       726.7
#
#                          Budget  Bond Actor Salary
# Film
# The World Is Not Enough   158.3               13.5
# Die Another Day           154.2               17.9
# Casino Royale             145.3                3.3
# Quantum of Solace         181.4                8.1
# Skyfall                   170.2               14.5
# Spectre                   206.3                NaN

# %%
bond.iloc[:20]
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[:15]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# ...

# %%
bond.loc["Moonraker","Actor"]
bond.loc["Moonraker","Director"]
# Out:
# 'Lewis Gilbert'

# %%
bond.loc[["Moonraker","A View to a Kill"],["Director","Box Office"]]
# Out:
#                        Director  Box Office
# Film
# Moonraker         Lewis Gilbert       535.0
# A View to a Kill      John Glen       275.2

# %%
bond.loc["Moonraker":"Thunderball","Director":"Budget"]
# Out:
#                                        Director  Box Office  Budget
# Film
# Moonraker                         Lewis Gilbert       535.0    91.5
# Never Say Never Again            Irvin Kershner       380.0    86.0
# Octopussy                             John Glen       373.8    53.9
# On Her Majesty's Secret Service   Peter R. Hunt       291.5    37.3
# Quantum of Solace                  Marc Forster       514.2   181.4
# Skyfall                              Sam Mendes       943.5   170.2
# Spectre                              Sam Mendes       726.7   206.3
# The Living Daylights                  John Glen       313.5    68.8
# The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me              Lewis Gilbert       533.0    45.1
# The World Is Not Enough           Michael Apted       439.5   158.3
# Thunderball                       Terence Young       848.1    41.9

# %%
bond.loc[:"Moonraker",:"Budget"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# ...

# %%
bond.iloc[14,2]
# Out:
# 'John Glen'

# %%
bond.iloc[14,2:5]
# Out:
# Director      John Glen
# Box Office        373.8
# Budget             53.9
# Name: Octopussy, dtype: object

# %%
bond.iloc[[4,17],[2,4]]
# Out:
#                      Director  Budget
# Film
# Die Another Day  Lee Tamahori   154.2
# Skyfall            Sam Mendes   170.2

# %%
bond.iloc[:7,:3]
# Out:
#                       Year           Actor         Director
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
# Dr. No                1962    Sean Connery    Terence Young
# For Your Eyes Only    1981     Roger Moore        John Glen

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Dr. No","Actor"]="Sir Sean Connery"

# %%
bond.loc["Dr. No","Actor"]
# Out:
# 'Sir Sean Connery'

# %%
bond.loc["Dr. No",["Box Office","Budget","Bond Actor Salary"]]=[4400,5500,6600]

# %%
bond.loc["Dr. No","Box Office"]
# Out:
# 4400.0

# %%
actor_shan=bond["Actor"]=="Sean Connery"

# %%
bond[actor_shan]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.loc[actor_shan,"Actor"]="Sir Sean Connery"

# %%
import pandas as pd

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.rename(mapper={"GoldenEye":"Golden Eye",
                    "The World Is Not Enough":"Best bond Movie Ever"})
bond.rename(index={"GoldenEye":"Golden Eye",
                    "The World Is Not Enough":"Best bond Movie Ever"})
bond.rename(mapper={"GoldenEye":"Golden Eye",
                    "The World Is Not Enough":"Best bond Movie Ever"},axis=0)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.rename(mapper={ "Year":"Release Date","Box Office":"Revenue"},axis=1)
bond.rename(mapper={ "Year":"Release Date","Box Office":"Revenue"},axis="columns")
bond.rename(index={ "Year":"Release Date","Box Office":"Revenue"})
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.columns=["Year of Release","Actor","Director","Box Office","Budget","Bond Actor Salary"]

# %%
bond.head(1)
# Out:
#                   Year of Release        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill             1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.drop("A View to a Kill")
# Out:
#                                  Year of Release           Actor  \
# Film
# Casino Royale                               2006    Daniel Craig
# Casino Royale                               1967     David Niven
# Diamonds Are Forever                        1971    Sean Connery
# Die Another Day                             2002  Pierce Brosnan
# Dr. No                                      1962    Sean Connery
# For Your Eyes Only                          1981     Roger Moore
# From Russia with Love                       1963    Sean Connery
# GoldenEye                                   1995  Pierce Brosnan
# Goldfinger                                  1964    Sean Connery
# Licence to Kill                             1989  Timothy Dalton
# Live and Let Die                            1973     Roger Moore
# Moonraker                                   1979     Roger Moore
# Never Say Never Again                       1983    Sean Connery
# ...

# %%
bond.drop(["A View to a Kill","Die Another Day","From Russia with Love"])
# Out:
#                                  Year of Release           Actor  \
# Film
# Casino Royale                               2006    Daniel Craig
# Casino Royale                               1967     David Niven
# Diamonds Are Forever                        1971    Sean Connery
# Dr. No                                      1962    Sean Connery
# For Your Eyes Only                          1981     Roger Moore
# GoldenEye                                   1995  Pierce Brosnan
# Goldfinger                                  1964    Sean Connery
# Licence to Kill                             1989  Timothy Dalton
# Live and Let Die                            1973     Roger Moore
# Moonraker                                   1979     Roger Moore
# Never Say Never Again                       1983    Sean Connery
# Octopussy                                   1983     Roger Moore
# On Her Majesty's Secret Service             1969  George Lazenby
# ...

# %%
bond.drop(["Box Office","Actor"],axis=1)
# Out:
#                                  Year of Release            Director  Budget  \
# Film
# A View to a Kill                            1985           John Glen    54.5
# Casino Royale                               2006     Martin Campbell   145.3
# Casino Royale                               1967          Ken Hughes    85.0
# Diamonds Are Forever                        1971        Guy Hamilton    34.7
# Die Another Day                             2002        Lee Tamahori   154.2
# Dr. No                                      1962       Terence Young     7.0
# For Your Eyes Only                          1981           John Glen    60.2
# From Russia with Love                       1963       Terence Young    12.6
# GoldenEye                                   1995     Martin Campbell    76.9
# Goldfinger                                  1964        Guy Hamilton    18.6
# Licence to Kill                             1989           John Glen    56.7
# ...

# %%
actor=bond.pop("Director")

# %%
actor
# Out:
# Film
# A View to a Kill                            John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
bond
# Out:
#                                  Year of Release           Actor  Box Office  \
# Film
# A View to a Kill                            1985     Roger Moore       275.2
# Casino Royale                               2006    Daniel Craig       581.5
# Casino Royale                               1967     David Niven       315.0
# Diamonds Are Forever                        1971    Sean Connery       442.5
# Die Another Day                             2002  Pierce Brosnan       465.4
# Dr. No                                      1962    Sean Connery       448.8
# For Your Eyes Only                          1981     Roger Moore       449.4
# From Russia with Love                       1963    Sean Connery       543.8
# GoldenEye                                   1995  Pierce Brosnan       518.5
# Goldfinger                                  1964    Sean Connery       820.4
# Licence to Kill                             1989  Timothy Dalton       250.9
# ...

# %%
del bond["Year of Release"]

# %%
bond
# Out:
#                                           Actor  Box Office  Budget  \
# Film
# A View to a Kill                    Roger Moore       275.2    54.5
# Casino Royale                      Daniel Craig       581.5   145.3
# Casino Royale                       David Niven       315.0    85.0
# Diamonds Are Forever               Sean Connery       442.5    34.7
# Die Another Day                  Pierce Brosnan       465.4   154.2
# Dr. No                             Sean Connery       448.8     7.0
# For Your Eyes Only                  Roger Moore       449.4    60.2
# From Russia with Love              Sean Connery       543.8    12.6
# GoldenEye                        Pierce Brosnan       518.5    76.9
# Goldfinger                         Sean Connery       820.4    18.6
# Licence to Kill                  Timothy Dalton       250.9    56.7
# Live and Let Die                    Roger Moore       460.3    30.8
# Moonraker                           Roger Moore       535.0    91.5
# ...

# %%
 bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n=5)
# Out:
#                          Year           Actor            Director  Box Office  \
# Film
# Octopussy                1983     Roger Moore           John Glen       373.8
# Moonraker                1979     Roger Moore       Lewis Gilbert       535.0
# Tomorrow Never Dies      1997  Pierce Brosnan  Roger Spottiswoode       463.2
# The World Is Not Enough  1999  Pierce Brosnan       Michael Apted       439.5
# You Only Live Twice      1967    Sean Connery       Lewis Gilbert       514.2
#
#                          Budget  Bond Actor Salary
# Film
# Octopussy                  53.9                7.8
# Moonraker                  91.5                NaN
# Tomorrow Never Dies       133.9               10.0
# The World Is Not Enough   158.3               13.5
# You Only Live Twice        59.9                4.4

# %%
 bond.sample(n=3,axis=0)
# Out:
#                        Year         Actor         Director  Box Office  \
# Film
# Casino Royale          2006  Daniel Craig  Martin Campbell       581.5
# Goldfinger             1964  Sean Connery     Guy Hamilton       820.4
# Never Say Never Again  1983  Sean Connery   Irvin Kershner       380.0
#
#                        Budget  Bond Actor Salary
# Film
# Casino Royale           145.3                3.3
# Goldfinger               18.6                3.2
# Never Say Never Again    86.0                NaN

# %%
bond.sort_values("Box Office",ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3,columns="Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond["Box Office"].nlargest()
# Out:
# Film
# Skyfall          943.5
# Thunderball      848.1
# Goldfinger       820.4
# Spectre          726.7
# Casino Royale    581.5
# Name: Box Office, dtype: float64

# %%
bond["Year"].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %%
mask=bond["Actor"]=="Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
bond.where(bond["Box Office"]>800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask2=bond["Box Office"]>800

# %%
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
bond.query('Actor =="Sean Connery"')
bond.query("Director=='Terence Young'")
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor!='Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
[column_name.replace(" ","_") for column_name in bond.columns]
# Out:
# ['Year', 'Actor', 'Director', 'Box_Office', 'Budget', 'Bond_Actor_Salary']

# %%
bond.query("Actor=='Roger Moore' and Director=='John Glen'" )
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond Actor Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
bond.query("Actor in ['Timothy Dalton','George Lazenby']")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2

# %%
bond.query("Actor not in ['Timothy Dalton','George Lazenby']")
# Out:
#                              Year           Actor            Director  \
# Film
# A View to a Kill             1985     Roger Moore           John Glen
# Casino Royale                2006    Daniel Craig     Martin Campbell
# Casino Royale                1967     David Niven          Ken Hughes
# Diamonds Are Forever         1971    Sean Connery        Guy Hamilton
# Die Another Day              2002  Pierce Brosnan        Lee Tamahori
# Dr. No                       1962    Sean Connery       Terence Young
# For Your Eyes Only           1981     Roger Moore           John Glen
# From Russia with Love        1963    Sean Connery       Terence Young
# GoldenEye                    1995  Pierce Brosnan     Martin Campbell
# Goldfinger                   1964    Sean Connery        Guy Hamilton
# Live and Let Die             1973     Roger Moore        Guy Hamilton
# Moonraker                    1979     Roger Moore       Lewis Gilbert
# ...

# %%
 bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def con_str(number):
    return str(number) + "Millions!"

# %%
bond["Box Office"].apply(con_str)
# Out:
# Film
# A View to a Kill                   275.2 Millions!Millions!
# Casino Royale                      581.5 Millions!Millions!
# Casino Royale                      315.0 Millions!Millions!
# Diamonds Are Forever               442.5 Millions!Millions!
# Die Another Day                    465.4 Millions!Millions!
# Dr. No                             448.8 Millions!Millions!
# For Your Eyes Only                 449.4 Millions!Millions!
# From Russia with Love              543.8 Millions!Millions!
# GoldenEye                          518.5 Millions!Millions!
# Goldfinger                         820.4 Millions!Millions!
# Licence to Kill                    250.9 Millions!Millions!
# Live and Let Die                   460.3 Millions!Millions!
# Moonraker                          535.0 Millions!Millions!
# Never Say Never Again              380.0 Millions!Millions!
# Octopussy                          373.8 Millions!Millions!
# On Her Majesty's Secret Service    291.5 Millions!Millions!
# ...

# %%
bond["Budget"].apply(con_str)
# Out:
# Film
# A View to a Kill                    54.5 Millions!
# Casino Royale                      145.3 Millions!
# Casino Royale                       85.0 Millions!
# Diamonds Are Forever                34.7 Millions!
# Die Another Day                    154.2 Millions!
# Dr. No                               7.0 Millions!
# For Your Eyes Only                  60.2 Millions!
# From Russia with Love               12.6 Millions!
# GoldenEye                           76.9 Millions!
# Goldfinger                          18.6 Millions!
# Licence to Kill                     56.7 Millions!
# Live and Let Die                    30.8 Millions!
# Moonraker                           91.5 Millions!
# Never Say Never Again               86.0 Millions!
# Octopussy                           53.9 Millions!
# On Her Majesty's Secret Service     37.3 Millions!
# Quantum of Solace                  181.4 Millions!
# Skyfall                            170.2 Millions!
# ...

# %%
columns=["Box Office","Budget","Bond Actor Salary"]
for col in columns:
    bond[col]=bond[col].apply(con_str)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen
# Casino Royale     2006  Daniel Craig  Martin Campbell
# Casino Royale     1967   David Niven       Ken Hughes
#
#                                                          Box Office  Budget  \
# Film
# A View to a Kill  275.2MillionsMillionsMillions!Millions! Millions!    54.5
# Casino Royale     581.5MillionsMillionsMillions!Millions! Millions!   145.3
# Casino Royale     315.0MillionsMillionsMillions!Millions! Millions!    85.0
#
#                   Bond Actor Salary     Box office
# Film
# A View to a Kill                9.1  275.2Millions
# Casino Royale                   3.3  581.5Millions
# Casino Royale                   NaN  315.0Millions

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def con_str(number):
    return str(number) + " Millions!"

# %%
columns=["Box Office","Budget","Bond Actor Salary"]
for col in columns:
    bond[col]=bond[col].apply(con_str)

# %%
bond.head()
# Out:
#                       Year           Actor         Director       Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2 Millions!
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5 Millions!
# Casino Royale         1967     David Niven       Ken Hughes  315.0 Millions!
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5 Millions!
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4 Millions!
#
#                                Budget Bond Actor Salary
# Film
# A View to a Kill       54.5 Millions!     9.1 Millions!
# Casino Royale         145.3 Millions!     3.3 Millions!
# Casino Royale          85.0 Millions!     nan Millions!
# Diamonds Are Forever   34.7 Millions!     5.8 Millions!
# Die Another Day       154.2 Millions!    17.9 Millions!

# %%
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    actor = row[1]
    budget = row[4]
    if actor == "Pierce Brosnan":
        return "The best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"

bond["Movie Category"] =bond.apply(good_movie, axis=1)
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_9556\2333426094.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   actor = row[1]
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_9556\2333426094.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   budget = row[4]

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
director=bond["Director"]
director.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
director["A View to a Kill"]="Mister john Glen"
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_9556\1316646481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   director["A View to a Kill"]="Mister john Glen"

# %%
director.head(3)
# Out:
# Film
# A View to a Kill    Mister john Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head()
# Out:
#                       Year           Actor          Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore  Mister john Glen       275.2
# Casino Royale         2006    Daniel Craig   Martin Campbell       581.5
# Casino Royale         1967     David Niven        Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery      Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan      Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary  Movie Category
# Film
# A View to a Kill        54.5                9.1       Enjoyable
# Casino Royale          145.3                3.3  I have no clue
# Casino Royale           85.0                NaN  I have no clue
# Diamonds Are Forever    34.7                5.8  I have no clue
# Die Another Day        154.2               17.9        The best

# %%
director=bond["Director"].copy()

# %%
director.head()
# Out:
# Film
# A View to a Kill              John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
director["A View to a Kill"]="Mister john Glen"

# %%
director.head()
# Out:
# Film
# A View to a Kill        Mister john Glen
# Casino Royale            Martin Campbell
# Casino Royale                 Ken Hughes
# Diamonds Are Forever        Guy Hamilton
# Die Another Day             Lee Tamahori
# Name: Director, dtype: object

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...
