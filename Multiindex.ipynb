# %%
import pandas as pd

# %%
bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"])
bigmac
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\1635062141.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"])
#           Date        Country  Price in US Dollars
# 0   2016-01-01      Argentina                 2.39
# 1   2016-01-01      Australia                 3.74
# 2   2016-01-01         Brazil                 3.35
# 3   2016-01-01        Britain                 4.22
# 4   2016-01-01         Canada                 4.14
# ..         ...            ...                  ...
# 647 2010-01-01         Turkey                 3.83
# 648 2010-01-01            UAE                 2.99
# 649 2010-01-01        Ukraine                 1.83
# 650 2010-01-01  United States                 3.58
# 651 2010-01-01        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
bigmac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %%
bigmac.nunique()
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
bigmac.set_index(keys=["Country","Date"],inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2016-01-01                 2.39
# Australia 2016-01-01                 3.74
# Brazil    2016-01-01                 3.35

# %%
bigmac.sort_index()
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
#           2010-07-01                 3.56
#           2011-07-01                 4.84
#           2012-01-01                 4.64
#           2012-07-01                 4.16
# ...                                   ...
# Vietnam   2014-01-01                 2.84
#           2014-07-01                 2.83
#           2015-01-01                 2.81
#           2015-07-01                 2.75
#           2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
bigmac.index
# Out:
# MultiIndex([(     'Argentina', '2016-01-01'),
#             (     'Australia', '2016-01-01'),
#             (        'Brazil', '2016-01-01'),
#             (       'Britain', '2016-01-01'),
#             (        'Canada', '2016-01-01'),
#             (         'Chile', '2016-01-01'),
#             (         'China', '2016-01-01'),
#             (      'Colombia', '2016-01-01'),
#             (    'Costa Rica', '2016-01-01'),
#             ('Czech Republic', '2016-01-01'),
#             ...
#             (     'Sri Lanka', '2010-01-01'),
#             (        'Sweden', '2010-01-01'),
#             (   'Switzerland', '2010-01-01'),
#             (        'Taiwan', '2010-01-01'),
#             (      'Thailand', '2010-01-01'),
#             (        'Turkey', '2010-01-01'),
#             (           'UAE', '2010-01-01'),
#             (       'Ukraine', '2010-01-01'),
#             ( 'United States', '2010-01-01'),
#             (       'Uruguay', '2010-01-01')],
# ...

# %%
bigmac.index.names
# Out:
# FrozenList(['Country', 'Date'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
type(bigmac.index[10])
# Out:
# tuple

# %%
bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\3960328641.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index.get_level_values("Date")
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values("Country")
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac.index.set_names(names=["Day","Location"],inplace="True")

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index.set_names(names="Date",level=0)
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.set_names(names="Date",level="Day",inplace=True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
bigmac.head()
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\3960328641.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.sort_index()
bigmac.sort_index(ascending=False)
bigmac.sort_index(ascending=[True,False])
bigmac.sort_index(ascending=[False,True])
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                     2.39
#            Australia                     3.74
#            Austria                       3.76
#            Belgium                       4.25
#            Brazil                        3.35
# ...                                       ...
# 2010-01-01 Turkey                        3.83
#            UAE                           2.99
#            Ukraine                       1.83
#            United States                 3.58
#            Uruguay                       3.32
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(level=0)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(level="Date")
bigmac.sort_index(level=0)
bigmac.sort_index(level="Country")
bigmac.sort_index(level=1)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16
# ...                                   ...
# 2014-01-01 Vietnam                   2.84
# 2014-07-01 Vietnam                   2.83
# 2015-01-01 Vietnam                   2.81
# 2015-07-01 Vietnam                   2.75
# 2016-01-01 Vietnam                   2.67
#
# [652 rows x 1 columns]

# %%
bigmac.loc["2010-01-01","Argentina"]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc["2010-01-01","Price in US Dollars"]
# Out:
# Country
# Argentina         1.84
# Australia         3.98
# Brazil            4.76
# Britain           3.67
# Canada            3.97
# Chile             3.18
# China             1.83
# Colombia          3.91
# Costa Rica        3.52
# Czech Republic    3.71
# Denmark           5.99
# Egypt             2.38
# Euro area         4.84
# Hong Kong         1.91
# Hungary           3.86
# Indonesia         2.24
# Israel            3.99
# Japan             3.50
# Latvia            3.09
# Lithuania         2.87
# Malaysia          2.08
# Mexico            2.50
# New Zealand       3.61
# Norway            7.02
# Pakistan          2.42
# Peru              2.81
# Philippines       2.21
# Poland            2.86
# Russia            2.34
# Saudi Arabia      2.67
# Singapore         3.19
# South Africa      2.46
# South Korea       2.98
# Sri Lanka         1.83
# Sweden            5.51
# Switzerland       6.30
# Taiwan            2.36
# Thailand          2.11
# Turkey            3.83
# ...

# %%
bigmac.loc[("2010-01-01","Argentina"),["Price in US Dollars","Price in US Dollars"]]
# Out:
# Price in US Dollars    1.84
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc[("2010-01-01",)]
# Out:
#                 Price in US Dollars
# Country
# Argentina                      1.84
# Australia                      3.98
# Brazil                         4.76
# Britain                        3.67
# Canada                         3.97
# Chile                          3.18
# China                          1.83
# Colombia                       3.91
# Costa Rica                     3.52
# Czech Republic                 3.71
# Denmark                        5.99
# Egypt                          2.38
# Euro area                      4.84
# Hong Kong                      1.91
# Hungary                        3.86
# Indonesia                      2.24
# Israel                         3.99
# Japan                          3.50
# Latvia                         3.09
# Lithuania                      2.87
# Malaysia                       2.08
# Mexico                         2.50
# New Zealand                    3.61
# Norway                         7.02
# Pakistan                       2.42
# ...

# %%
bigmac.iloc[0]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.iloc[[10,20,30,250]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                   5.99
#            Malaysia                  2.08
#            Singapore                 3.19
# 2012-07-01 Turkey                    4.52

# %%
bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\1200440920.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac=pd.read_csv("bigmac.csv",parse_dates=["Date"],index_col=["Date","Country"])
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac=bigmac.transpose()
bigmac.head(3)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
 bigmac.loc[("Price in US Dollars",), ("2010-01-01", "Sri Lanka"):("2010-01-01", "Ukraine")]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %%
im
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\716301466.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bigmac = pd.read_csv("bigmac.csv", parse_dates=["Date"], index_col=["Date", "Country"])

# %%
# Out:
#                 Price in US Dollars
# Country
# Argentina                      1.84
# Australia                      3.98
# Brazil                         4.76
# Britain                        3.67
# Canada                         3.97
# Chile                          3.18
# China                          1.83
# Colombia                       3.91
# Costa Rica                     3.52
# Czech Republic                 3.71
# Denmark                        5.99
# Egypt                          2.38
# Euro area                      4.84
# Hong Kong                      1.91
# Hungary                        3.86
# Indonesia                      2.24
# Israel                         3.99
# Japan                          3.50
# Latvia                         3.09
# Lithuania                      2.87
# Malaysia                       2.08
# Mexico                         2.50
# New Zealand                    3.61
# Norway                         7.02
# Pakistan                       2.42
# ...

# %%
bigmac.swaplevel("Date","Country")
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
world=pd.read_csv("worldstats.csv",index_col=["country","year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
world.stack()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
s=world.stack()
s
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
s.unstack().unstack().unstack()
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
s=world.stack()
s
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
s.unstack(1)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
s.unstack("country")
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
s.unstack(level=[0,1])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack(level=["year","country"])
# Out:
# year                2015          2014          2013          2012  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# year                2011          2010          2009          2008  \
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# year                2007          2006  ...          1969          1968  \
# country       Arab World    Arab World  ...      Zimbabwe      Zimbabwe
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# year                1967          1966          1965          1964  \
# ...

# %%
s=s.unstack("year",fill_value=0)

# %%
s.head()
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
#             GDP         7.511112e+08  8.000000e+08  1.006667e+09
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.198513e+07  1.229597e+07  1.262695e+07
#
# year                            1966          1967          1968  \
# country
# Afghanistan Population  1.014884e+07  1.036860e+07  1.059979e+07
# ...

# %%
sales=pd.read_csv("salesmen.csv",parse_dates=["Date"])
sales.head()
# Out:
# C:\Users\Muhammad Shahbaz\AppData\Local\Temp\ipykernel_10044\149855344.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales=pd.read_csv("salesmen.csv",parse_dates=["Date"])
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982
# 3 2016-01-04      Bob     7917
# 4 2016-01-05      Bob     7837

# %%
len(sales)
# Out:
# 1830

# %%
sales.pivot(index="Date",columns="Salesman",values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
foods=pd.read_csv("foods.csv")
foods
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# ..         ...     ...           ...       ...        ...    ...
# 995      Donna  Female      New York   Monthly      Sushi  83.53
# 996     Albert    Male  Philadelphia     Daily      Sushi  72.88
# 997       Jean  Female      Stamford    Weekly      Donut   5.85
# 998    Jessica  Female      New York     Daily    Chalupa  43.19
# 999      Brian    Male      New York     Daily    Chalupa  28.36
#
# [1000 rows x 6 columns]

# %%
foods.pivot_table(values="Spend",index=["Gender","Item"],columns=["City","Frequency"],aggfunc="mean").head(3)
# Out:
# City             New York                                                   \
# Frequency           Daily    Monthly    Never      Often       Once Seldom
# Gender Item
# Female Burger   43.778333  57.286667  97.8900  23.740000  52.425000  31.58
#        Burrito  44.890000  40.913333  47.4325  34.533333  59.940000  83.77
#        Chalupa  43.190000  79.185000  35.1500  39.730000  36.933333  40.00
#
# City                              Philadelphia           ...             \
# Frequency       Weekly     Yearly        Daily  Monthly  ...     Weekly
# Gender Item                                              ...
# Female Burger   92.175  64.825000    77.226667  53.7625  ...  16.000000
#        Burrito  13.230  35.630000    53.595000  17.1400  ...  31.410000
#        Chalupa  42.880  52.606667    23.490000  72.4900  ...  28.136667
#
# City                      Stamford                                            \
# ...

# %%
foods.pivot_table(values="Spend",index=["Gender","Item"],columns=["City","Frequency"],aggfunc="mean").head(3)
# Out:
# City             New York                                                   \
# Frequency           Daily    Monthly    Never      Often       Once Seldom
# Gender Item
# Female Burger   43.778333  57.286667  97.8900  23.740000  52.425000  31.58
#        Burrito  44.890000  40.913333  47.4325  34.533333  59.940000  83.77
#        Chalupa  43.190000  79.185000  35.1500  39.730000  36.933333  40.00
#
# City                              Philadelphia           ...             \
# Frequency       Weekly     Yearly        Daily  Monthly  ...     Weekly
# Gender Item                                              ...
# Female Burger   92.175  64.825000    77.226667  53.7625  ...  16.000000
#        Burrito  13.230  35.630000    53.595000  17.1400  ...  31.410000
#        Chalupa  42.880  52.606667    23.490000  72.4900  ...  28.136667
#
# City                      Stamford                                            \
# ...

# %%
sales=pd.read_csv("quarters.csv")
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales,id_vars="Salesman",var_name="Quarter",value_name="Revenue")
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
